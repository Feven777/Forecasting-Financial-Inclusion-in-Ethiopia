# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
DATA_PATH = "../data/raw/"

df = pd.read_csv(f"{DATA_PATH}/ethiopia_fi_unified_data.csv")
ref = pd.read_csv(f"{DATA_PATH}/reference_codes.csv")

print("Unified dataset shape:", df.shape)
print("Reference codes shape:", ref.shape)
# Out:
# Unified dataset shape: (43, 34)
# Reference codes shape: (71, 4)

# %%
df.head(10)
# Out:
#   record_id  record_type category  pillar                  indicator  indicator_code indicator_direction  \
# 0  REC_0001  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 1  REC_0002  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 2  REC_0003  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 3  REC_0004  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 4  REC_0005  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 5  REC_0006  observation      NaN  ACCESS     Account Ownership Rate   ACC_OWNERSHIP       higher_better
# 6  REC_0007  observation      NaN  ACCESS  Mobile Money Account Rate  ACC_MM_ACCOUNT       higher_better
# 7  REC_0008  observation      NaN  ACCESS  Mobile Money Account Rate  ACC_MM_ACCOUNT       higher_better
# 8  REC_0009  observation      NaN  ACCESS     4G Population Coverage      ACC_4G_COV       higher_better
# 9  REC_0010  observation      NaN  ACCESS     4G Population Coverage      ACC_4G_COV       higher_better
#
#    value_numeric value_text  value_type unit observation_date period_start  period_end fiscal_year  gender  location  \
# 0          22.00        NaN  percentage    %       2014-12-31          NaN         NaN        2014     all  national
# 1          35.00        NaN  percentage    %       2017-12-31          NaN         NaN        2017     all  national
# 2          46.00        NaN  percentage    %       2021-12-31          NaN         NaN        2021     all  national
# 3          56.00        NaN  percentage    %       2021-12-31          NaN         NaN        2021    male  national
# 4          36.00        NaN  percentage    %       2021-12-31          NaN         NaN        2021  female  national
# 5          49.00        NaN  percentage    %       2024-11-29   2024-10-15  2024-11-29        2024     all  national
# 6           4.70        NaN  percentage    %       2021-12-31          NaN         NaN        2021     all  national
# 7           9.45        NaN  percentage    %       2024-11-29          NaN         NaN        2024     all  national
# 8          37.50        NaN  percentage    %       2023-06-30          NaN         NaN   FY2022/23     all  national
# 9          70.80        NaN  percentage    %       2025-06-30          NaN         NaN   FY2024/25     all  national
#
#    region                source_name source_type                                         source_url confidence  \
# 0     NaN         Global Findex 2014      survey  https://www.worldbank.org/en/publication/globa...       high
# 1     NaN         Global Findex 2017      survey  https://www.worldbank.org/en/publication/globa...       high
# 2     NaN         Global Findex 2021      survey  https://www.worldbank.org/en/publication/globa...       high
# 3     NaN         Global Findex 2021      survey  https://www.worldbank.org/en/publication/globa...       high
# 4     NaN         Global Findex 2021      survey  https://www.worldbank.org/en/publication/globa...       high
# 5     NaN         Global Findex 2024      survey  https://www.worldbank.org/en/publication/globa...       high
# 6     NaN         Global Findex 2021      survey  https://www.worldbank.org/en/publication/globa...       high
# 7     NaN         Global Findex 2024      survey  https://www.worldbank.org/en/publication/globa...       high
# 8     NaN  Ethio Telecom LEAD Report    operator                       https://www.ethiotelecom.et/       high
# 9     NaN  Ethio Telecom LEAD Report    operator                       https://www.ethiotelecom.et/       high
#
#    related_indicator  relationship_type  impact_direction  impact_magnitude  impact_estimate  lag_months  \
# 0                NaN                NaN               NaN               NaN              NaN         NaN
# 1                NaN                NaN               NaN               NaN              NaN         NaN
# 2                NaN                NaN               NaN               NaN              NaN         NaN
# 3                NaN                NaN               NaN               NaN              NaN         NaN
# 4                NaN                NaN               NaN               NaN              NaN         NaN
# 5                NaN                NaN               NaN               NaN              NaN         NaN
# 6                NaN                NaN               NaN               NaN              NaN         NaN
# 7                NaN                NaN               NaN               NaN              NaN         NaN
# 8                NaN                NaN               NaN               NaN              NaN         NaN
# 9                NaN                NaN               NaN               NaN              NaN         NaN
#
#    evidence_basis comparable_country collected_by                              collection_date  \
# 0             NaN    Example_Trainee   2025-01-20                                          NaN
# 1             NaN    Example_Trainee   2025-01-20                                          NaN
# 2             NaN    Example_Trainee   2025-01-20                                          NaN
# 3             NaN    Example_Trainee   2025-01-20                                          NaN
# 4             NaN    Example_Trainee   2025-01-20                                          NaN
# 5             NaN    Example_Trainee   2025-01-20  Account ownership increased from 46% to 49%
# 6             NaN    Example_Trainee   2025-01-20                                          NaN
# 7             NaN    Example_Trainee   2025-01-20                                          NaN
# 8             NaN    Example_Trainee   2025-01-20                                          NaN
# 9             NaN    Example_Trainee   2025-01-20      4G coverage doubled from 37.5% to 70.8%
#
#                      original_text  notes
# 0                    Baseline year    NaN
# 1                              NaN    NaN
# 2                              NaN    NaN
# 3             Gender disaggregated    NaN
# 4             Gender disaggregated    NaN
# 5              Survey Oct-Nov 2024    NaN
# 6                              NaN    NaN
# 7                Doubled from 2021    NaN
# 8           Before major expansion    NaN
# 9  Major infrastructure investment    NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            43 non-null     str
#  1   record_type          43 non-null     str
#  2   category             10 non-null     str
#  3   pillar               33 non-null     str
#  4   indicator            43 non-null     str
#  5   indicator_code       43 non-null     str
#  6   indicator_direction  33 non-null     str
#  7   value_numeric        33 non-null     float64
#  8   value_text           10 non-null     str
#  9   value_type           43 non-null     str
#  10  unit                 33 non-null     str
#  11  observation_date     43 non-null     str
#  12  period_start         10 non-null     str
#  13  period_end           10 non-null     str
#  14  fiscal_year          43 non-null     str
#  15  gender               43 non-null     str
#  16  location             43 non-null     str
#  17  region               0 non-null      float64
#  18  source_name          43 non-null     str
#  19  source_type          43 non-null     str
#  20  source_url           31 non-null     str
#  21  confidence           43 non-null     str
#  22  related_indicator    0 non-null      float64
#  23  relationship_type    0 non-null      float64
#  24  impact_direction     0 non-null      float64
#  25  impact_magnitude     0 non-null      float64
#  26  impact_estimate      0 non-null      float64
#  27  lag_months           0 non-null      float64
#  28  evidence_basis       0 non-null      float64
#  29  comparable_country   43 non-null     str
#  30  collected_by         43 non-null     str
#  31  collection_date      10 non-null     str
#  32  original_text        33 non-null     str
#  33  notes                0 non-null      float64
# dtypes: float64(10), str(24)
# memory usage: 11.6 KB

# %%
df["record_type"].value_counts()
# Out:
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64

# %%
df.groupby(["record_type", "pillar"]).size().reset_index(name="count")
# Out:
#    record_type         pillar  count
# 0  observation         ACCESS     14
# 1  observation  AFFORDABILITY      1
# 2  observation         GENDER      4
# 3  observation          USAGE     11
# 4       target         ACCESS      2
# 5       target         GENDER      1

# %%
df["observation_date"] = pd.to_datetime(df["observation_date"], errors="coerce")

df.groupby("record_type")["observation_date"].agg(["min", "max"])
# Out:
#                    min        max
# record_type
# event       2021-05-17 2025-12-18
# observation 2014-12-31 2025-12-31
# target      2025-12-31 2030-12-31

# %%
indicators = (
    df[df["record_type"] == "observation"]
    .groupby("indicator_code")["observation_date"]
    .agg(["count", "min", "max"])
    .sort_values("count", ascending=False)
)

indicators
# Out:
#                     count        min        max
# indicator_code
# ACC_OWNERSHIP           6 2014-12-31 2024-11-29
# ACC_FAYDA               3 2024-08-15 2025-05-15
# ACC_4G_COV              2 2023-06-30 2025-06-30
# ACC_MM_ACCOUNT          2 2021-12-31 2024-11-29
# GEN_GAP_ACC             2 2021-12-31 2024-11-29
# USG_P2P_COUNT           2 2024-07-07 2025-07-07
# ACC_MOBILE_PEN          1 2025-12-31 2025-12-31
# GEN_GAP_MOBILE          1 2024-12-31 2024-12-31
# GEN_MM_SHARE            1 2024-12-31 2024-12-31
# USG_ACTIVE_RATE         1 2024-12-31 2024-12-31
# AFF_DATA_INCOME         1 2024-12-31 2024-12-31
# USG_ATM_COUNT           1 2025-07-07 2025-07-07
# USG_ATM_VALUE           1 2025-07-07 2025-07-07
# USG_MPESA_ACTIVE        1 2024-12-31 2024-12-31
# USG_CROSSOVER           1 2025-07-07 2025-07-07
# USG_MPESA_USERS         1 2024-12-31 2024-12-31
# USG_P2P_VALUE           1 2025-07-07 2025-07-07
# USG_TELEBIRR_USERS      1 2025-06-30 2025-06-30
# USG_TELEBIRR_VALUE      1 2025-06-30 2025-06-30

# %%
events = df[df["record_type"] == "event"][[
    "record_id",
    "category",
    "indicator",        # event description
    "observation_date",
    "source_name",
    "confidence"
]]

events.sort_values("observation_date")
# Out:
#    record_id        category                               indicator observation_date    source_name confidence
# 33  EVT_0001  product_launch                         Telebirr Launch       2021-05-17  Ethio Telecom       high
# 41  EVT_0009          policy                 NFIS-II Strategy Launch       2021-09-01            NBE       high
# 34  EVT_0002    market_entry    Safaricom Ethiopia Commercial Launch       2022-08-01           News       high
# 35  EVT_0003  product_launch                  M-Pesa Ethiopia Launch       2023-08-01      Safaricom       high
# 36  EVT_0004  infrastructure        Fayda Digital ID Program Rollout       2024-01-01           NIDP       high
# 37  EVT_0005          policy         Foreign Exchange Liberalization       2024-07-29            NBE       high
# 38  EVT_0006       milestone     P2P Transaction Count Surpasses ATM       2024-10-01      EthSwitch       high
# 39  EVT_0007     partnership            M-Pesa EthSwitch Integration       2025-10-27      EthSwitch       high
# 42  EVT_0010         pricing       Safaricom Ethiopia Price Increase       2025-12-15           News       high
# 40  EVT_0008  infrastructure  EthioPay Instant Payment System Launch       2025-12-18  NBE/EthSwitch       high

# %%
df.columns.tolist()
# Out:
# ['record_id',
#  'record_type',
#  'category',
#  'pillar',
#  'indicator',
#  'indicator_code',
#  'indicator_direction',
#  'value_numeric',
#  'value_text',
#  'value_type',
#  'unit',
#  'observation_date',
#  'period_start',
#  'period_end',
#  'fiscal_year',
#  'gender',
#  'location',
#  'region',
#  'source_name',
#  'source_type',
#  'source_url',
#  'confidence',
#  'related_indicator',
#  'relationship_type',
#  'impact_direction',
#  'impact_magnitude',
#  'impact_estimate',
#  'lag_months',
#  'evidence_basis',
#  'comparable_country',
#  'collected_by',
#  'collection_date',
#  'original_text',
#  'notes']

# %%
df[df["record_type"] == "observation"]["indicator_code"].value_counts()
# Out:
# indicator_code
# ACC_OWNERSHIP         6
# ACC_FAYDA             3
# ACC_MM_ACCOUNT        2
# ACC_4G_COV            2
# USG_P2P_COUNT         2
# GEN_GAP_ACC           2
# ACC_MOBILE_PEN        1
# USG_P2P_VALUE         1
# USG_ATM_COUNT         1
# USG_ATM_VALUE         1
# USG_CROSSOVER         1
# USG_TELEBIRR_USERS    1
# USG_TELEBIRR_VALUE    1
# USG_MPESA_USERS       1
# USG_MPESA_ACTIVE      1
# USG_ACTIVE_RATE       1
# AFF_DATA_INCOME       1
# GEN_MM_SHARE          1
# GEN_GAP_MOBILE        1
# Name: count, dtype: int64

# %%
df[df["record_type"] == "observation"]["observation_date"].agg(["min", "max"])
# Out:
# min    2014-12-31
# max    2025-12-31
# Name: observation_date, dtype: str

# %%
df[df["record_type"] == "event"][
    [
        "record_id",
        "category",
        "period_start",
        "period_end",
        "notes",
        "original_text",
        "source_name",
        "confidence"
    ]
]
# Out:
#    record_id        category period_start  period_end  notes                                 original_text  \
# 33  EVT_0001  product_launch          NaN         NaN    NaN  First major mobile money service in Ethiopia
# 34  EVT_0002    market_entry          NaN         NaN    NaN                 End of state telecom monopoly
# 35  EVT_0003  product_launch          NaN         NaN    NaN                   Second mobile money entrant
# 36  EVT_0004  infrastructure          NaN         NaN    NaN          National biometric digital ID system
# 37  EVT_0005          policy          NaN         NaN    NaN                         Birr float introduced
# 38  EVT_0006       milestone          NaN         NaN    NaN       Historic: digital > cash for first time
# 39  EVT_0007     partnership          NaN         NaN    NaN              Full interoperability for M-Pesa
# 40  EVT_0008  infrastructure          NaN         NaN    NaN             National real-time payment system
# 41  EVT_0009          policy   2021-09-01  2025-06-30    NaN  5-year national financial inclusion strategy
# 42  EVT_0010         pricing          NaN         NaN    NaN        Data and voice prices increased 20-82%
#
#       source_name confidence
# 33  Ethio Telecom       high
# 34           News       high
# 35      Safaricom       high
# 36           NIDP       high
# 37            NBE       high
# 38      EthSwitch       high
# 39      EthSwitch       high
# 40  NBE/EthSwitch       high
# 41            NBE       high
# 42           News       high

# %%
df.columns.tolist()
# Out:
# ['record_id',
#  'record_type',
#  'category',
#  'pillar',
#  'indicator',
#  'indicator_code',
#  'indicator_direction',
#  'value_numeric',
#  'value_text',
#  'value_type',
#  'unit',
#  'observation_date',
#  'period_start',
#  'period_end',
#  'fiscal_year',
#  'gender',
#  'location',
#  'region',
#  'source_name',
#  'source_type',
#  'source_url',
#  'confidence',
#  'related_indicator',
#  'relationship_type',
#  'impact_direction',
#  'impact_magnitude',
#  'impact_estimate',
#  'lag_months',
#  'evidence_basis',
#  'comparable_country',
#  'collected_by',
#  'collection_date',
#  'original_text',
#  'notes']

# %%
impact_links = df[df["record_type"] == "impact_link"][[
    "pillar",
    "related_indicator",
    "relationship_type",
    "impact_direction",
    "impact_magnitude",
    "impact_estimate",
    "lag_months",
    "evidence_basis",
    "confidence"
]]

impact_links
# Out:
# Empty DataFrame
# Columns: [pillar, related_indicator, relationship_type, impact_direction, impact_magnitude, impact_estimate, lag_months, evidence_basis, confidence]
# Index: []

# %%
df["confidence"].value_counts(dropna=False)
# Out:
# confidence
# high      40
# medium     3
# Name: count, dtype: int64

# %%
df.groupby(["record_type", "confidence"]).size().unstack(fill_value=0)
# Out:
# confidence   high  medium
# record_type
# event          10       0
# observation    28       2
# target          2       1

# %%
obs = df[df["record_type"] == "observation"]

indicator_coverage = (
    obs.groupby("indicator_code")["observation_date"]
    .nunique()
    .sort_values(ascending=False)
)

indicator_coverage
# Out:
# indicator_code
# ACC_OWNERSHIP         4
# ACC_FAYDA             3
# ACC_4G_COV            2
# ACC_MM_ACCOUNT        2
# GEN_GAP_ACC           2
# USG_P2P_COUNT         2
# ACC_MOBILE_PEN        1
# GEN_GAP_MOBILE        1
# GEN_MM_SHARE          1
# USG_ACTIVE_RATE       1
# AFF_DATA_INCOME       1
# USG_ATM_COUNT         1
# USG_ATM_VALUE         1
# USG_MPESA_ACTIVE      1
# USG_CROSSOVER         1
# USG_MPESA_USERS       1
# USG_P2P_VALUE         1
# USG_TELEBIRR_USERS    1
# USG_TELEBIRR_VALUE    1
# Name: observation_date, dtype: int64

# %%
key_indicators = [
    "ACC_OWNERSHIP",
    "USG_DIGITAL_PAYMENT",
    "ACC_MM_ACCOUNT"
]

obs[obs["indicator_code"].isin(key_indicators)] \
    .groupby("indicator_code")["observation_date"] \
    .agg(["count", "min", "max"])
# Out:
#                 count        min        max
# indicator_code
# ACC_MM_ACCOUNT      2 2021-12-31 2024-11-29
# ACC_OWNERSHIP       6 2014-12-31 2024-11-29

# %%
enriched = pd.read_csv("../data/processed/ethiopia_fi_unified_data_enriched.csv")

enriched[
    (enriched["indicator_code"] == "ENB_SMARTPHONE_PCT")
    & (enriched["record_type"] == "observation")
][["indicator", "value_numeric", "observation_date", "confidence"]]
# Out:
#                      indicator  value_numeric observation_date confidence
# 0  Smartphone penetration rate             17       2018-01-01     medium
# 1  Smartphone penetration rate             23       2020-01-01     medium
# 2  Smartphone penetration rate             32       2023-01-01     medium

# %%
df["pillar"].unique()
df["record_type"].value_counts()
# Out:
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64
